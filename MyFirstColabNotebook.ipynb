# %% [markdown]
# <a href="https://colab.research.google.com/github/jreydc/jreydc/blob/main/MyFirstColabNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# John Rey D. Casingal - Holy Angel University

# %%
import time

print(time.ctime())
# Out:
# Tue Jul 13 00:59:59 2021

# %%
time.sleep(5)

print(time.ctime())
# Out:
# Tue Jul 13 00:59:55 2021
